# %% [markdown]
# # Local RAG Pipeline with HuggingFace Embeddings (Python 3.12)
# This notebook demonstrates how to:
# - Read local `.txt` and `.pdf` files
#     - This is good enough for 'playing' but production would need  many more examples of files AND longer files.
#     - A single service would not be enough

# %%
# %pip install --upgrade pip

# %pip install -q -r requirements.txt
# Out:
# Requirement already satisfied: pip in /Users/davidclare/Projects/jupyter-notebooks/.venv/lib/python3.12/site-packages (25.0.1)
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.

# %%
from pathlib import Path
from config import settings

# %%
docs_path: Path = settings.DATA_DIR
processed_path: Path = settings.PROCESSED_FILE

print(settings)
# Out:
# Settings(
#   BASE_PATH=.
#   DATA_DIR=data_sources
#   API_KEY=***
#   PROCESSED_FILE=processed_data.txt
# )

# %% [markdown]
# ## Base Strategy Interface

# %%
from pathlib import Path
from abc import ABC, abstractmethod


class FileHandler(ABC):
    @abstractmethod
    def can_handle(self, file_path: Path) -> bool: ## How robust is this?
        pass

    @abstractmethod
    def extract_text(self, file_path: Path) -> str: ## How robust is this? How do we know the text is extracted correctly?
        pass

# %% [markdown]
# ## The DocumentLoader

# %%
class DocumentLoader:
    def __init__(self):
        self.handlers: list[FileHandler] = []

    def register_handler(self, handler: FileHandler):
        self.handlers.append(handler)

    def extract_text(self, file_path: Path) -> str:
        for handler in self.handlers:
            if handler.can_handle(file_path): ## check if the handler can handle the file type
                ## if yes, call the extract_text method of the handler
                return handler.extract_text(file_path)
        raise ValueError(f"No handler for file type: {file_path.suffix}")

# %% [markdown]
# ## Text Handler

# %%
class TxtHandler(FileHandler):
    def can_handle(self, file_path: Path) -> bool:
        return file_path.suffix.lower() == ".txt"

    def extract_text(self, file_path: Path) -> str:
        return file_path.read_text(encoding="utf-8")

# %% [markdown]
# ## PDF Handler
# Note that PDFs can be encoded with text or as 'images' of text. This class checks and handles both cases

# %%
import PyPDF2
from pdf2image import convert_from_path
import pytesseract


class PdfHandler(FileHandler):
    def can_handle(self, file_path: Path) -> bool:
        return file_path.suffix.lower() == ".pdf"

    def is_text_based(self, file_path: Path) -> bool:
        try:
            with open(file_path, "rb") as f:
                reader = PyPDF2.PdfReader(f)
                return any(page.extract_text() for page in reader.pages)
        except:
            return False

    def extract_text(self, file_path: Path) -> str:
        if self.is_text_based(file_path):
            with open(file_path, "rb") as f:
                reader = PyPDF2.PdfReader(f)
                return "\n".join(page.extract_text() or "" for page in reader.pages)
        else:
            pages = convert_from_path(file_path)
            return "\n".join(pytesseract.image_to_string(p) for p in pages)

# %%
loader = DocumentLoader()
loader.register_handler(TxtHandler())
loader.register_handler(PdfHandler())

# %%
from dataclasses import dataclass
from typing import List, Dict

@dataclass
class TextFile:
    filename: str
    content: str


all_texts: List[TextFile] = []

# %%
for file in docs_path.glob("*"): ## Is this recursive?
    try:
        content = loader.extract_text(file)
        all_texts.append(TextFile(filename=file.name, content=content))
    except Exception as e:
        print(f"Error with {file.name}: {e}")

# %% [markdown]
# ## Check the documents have been processed

# %%
print(f"Extracted {len(all_texts)} documents.")
# Out:
# Extracted 5 documents.

# %%
print(all_texts[1])
# Out:
# TextFile(filename='LHH Values Audit Exercise.pdf', content='Values\nAudit\nValues are powerful principles or qualifications \nthat underpin our actions and our opinions \nabout events and people. Sometimes they are \ncalled ‘critical needs’ . \nValues change significantly over the years and \nit’s important to be clear about them and to \nbetter assess how they can be met. Decisions \nwe make often reflect what’s important in our \nlives. If there’s a conflict between a decision \nand your own values, very often this conflict \ncan contribute to both personal and career \ndissatisfaction and unhappiness. \nSources of strong dissatisfaction often occur \nwhen we have cherished values that are not \ncurrently being acted on or when we have two \nstrong values that are in conflict, such as a \ndesire for achievement and leisure. Often we’re \nnot fully aware of values that drive us, especially \nif they have always been satisfied. \n2\n© LHH. All rights reserved\nValues Audit Exercise\nDirections\n1. Review each of the values listed below. You will select from one of four columns: \nAlways Valued, Often Valued, Sometimes Valued and Rarely Valued.\n2. Check the column that best describes how important each value is to you right now at \nthis point in your life. Consider your choices carefully and use all of the columns.\n3. Please do not exceed 10 checks in the Always Valued column.\nAlways\nValuedOften\nValuedSometimes\nValuedRarely\nValued\n1 Personal Growth: Develop my potential\nand use my talents\n2 Achievement: Have a sense of\naccomplishment\n3 Knowledge: Develop and use specific\nknowledge\n4 Status: Hold a position of recognised\nimportance\n5 Change and Variety: Have job\nresponsibilities with varied tasks\n6 Service to Society: Contribute to a better\nsociety\n7 Physical Activity: Do work requiring\nstrength, agility, or physical exertion\n8 Independence: Control my own\nwork/schedule\n9 Leadership: Influence others to achieve\nresults\n10 Creative Expression: Express my\ncreativity and imagination in my work\n11 Challenge: Find work that stimulates me\nmentally\n12 Money: Reap significant financial rewards\nin my work\n13 Security: Perform my work without worry \nabout possible unemployment\n3\n© LHH. All rights reserved\nAlways\nValuedOften\nValuedSometimes\nValuedRarely\nValued\n14 Management: Achieve work goals as a\nresult of others’ efforts\n15 Work with Others: Belong to a satisfying work\n16 Power: Have control over resources at work\n17 Integrity: Work ethically and honestly\n18 Balance: Achieve the right proportion\nbetween my personal life and professional\nresponsibilities\n19 Friendship: Develop social/personal\nfriendships with work colleagues\n20 Career Advancement: Have opportunities\nwithin the organisation\n21 Detail Work: Deal with tasks that must\nmeet specifications requiring careful,\naccurate attention to detail\n22 Fast Pace: Work under time-pressured\ncircumstances with demanding expectations\n23 Helping Others: Involve myself in helping\nsociety and others\n24 Location: Live in a convenient geographic\nlocation in a suitable community\n25 Recognition: Receive credit for work well-\ndone\n26 Excitement: Frequent novelty and drama\n27 Moral Fulfilment: Work contributes to\nmoral ideals\n28 Aesthetics: Appreciate the beauty of things\nand ideas\n29 Health: Being physically and mentally fit\n30 Positive Atmosphere: Work in a\nsupportive, pleasing, harmonious setting\n31 Efficient Organisation: Being in a time-\nefficient environment with little bureaucracy\n32 Family Happiness: Good balance between \nwork and family life\n4\n© LHH. All rights reserved\nYour Priority Values\nA forced ranking of values helps you to clarify the trade-offs necessary to fulfill your most \nimportant needs.\nDirections\nWrite your Always Valued items in the first column below.\n1.Rank or\nder your Top 7 values in the second column.\n2.Now\n, look at your Top 7 priority values individually. Were these values fulfilled in  ...

# %%
with open(processed_path, "w", encoding="utf-8") as f: ## Open the file in write mode
    for doc in all_texts: ## Loop through the documents
        f.write(f"__META__FILE__NAME: {doc.filename}\n")
        f.write(f"__CONTENT__: {doc.content}\n")
        f.write("\n" + "="*80 + "\n\n")
